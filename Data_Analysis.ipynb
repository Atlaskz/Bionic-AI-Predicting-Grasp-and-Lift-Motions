# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Bionic AI/')
from functions import *

# %% [markdown]
# ## Import Individual Subjects's Data

# %%
# Training Data

subjects, events = getSubjectsData(testSeries=3,test=False)

# %%
## Testinsubjects_test, events_test = getSubjectsData(test_series=3,Test=True)

subjects_test, events_test = getSubjectsData(testSeries=3,test=True)

# %% [markdown]
# ## Visualizing All Trials

# %%
## Visualizing All Trials
graphTrials(3,3, oneTrial=False)

# %%
## Visualizing One Trial
graphTrials(3,3, oneTrial=True)

# %% [markdown]
# ## Visualizing a Single Event

# %%
eventsList = events[0].columns.tolist()
for ev in eventsList:
  getGraph(subjects[0],events[0],ev,16,3)
